# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-

# %%
import warnings; warnings.simplefilter('ignore')
import gensim as gen
import json
import codecs
import regex as re
import os.path
from scipy import spatial

import local_settings
import django
django.setup()

from sefaria.model import *
from sefaria.system.exceptions import InputError, PartialRefInputError
# Out:
# WARNING Failed to load 're2'.  Falling back to 're' for regular expression parsing. See https://github.com/blockspeiser/Sefaria-Project/wiki/Regular-Expression-Engines
# WARNING Failed to load 're2'.  Falling back to 're' for regular expression parsing. See https://github.com/Sefaria/Sefaria-Project/wiki/Regular-Expression-Engines

# %%
import hebrew_spellcheck

# %%
word_expander = hebrew_spellcheck.word_expander

# %%
stopwords = codecs.open('./hebrew_stopwords.txt', encoding='utf8').read().strip().split('\n')
stopwords_regex = u"(?:\s|^)({})(?=\s|$)".format(u"|".join(stopwords))
stopwords_regex = re.compile(stopwords_regex)

# %%
phrases = codecs.open('./select_phrases.txt', encoding='utf8').read().strip().split('\n')
phrases_regex = u"(\s|^)({})(?=\s|$)".format(u"|".join(phrases))
phrases_regex = re.compile(phrases_regex)

# %%
def get_talmud_topic_ranged():
    """
    Reads every file in the sugyot directory.  
    Each file in this directory contains semantically meaningful ranged refs for Talmud
    :return: List of all Talmudic Ranged Refs
    """
    all_gemara_topic_ranges = []
    for filename in os.listdir('./sugyot/'):
        with codecs.open('./sugyot/'+filename, 'rb', encoding='utf8') as csvfile:
            reader = csv.reader(csvfile)
            reader.next()
            all_gemara_topic_ranges += [row[0] for row in reader]
    return all_gemara_topic_ranges


def create_list_off_talmud_books():
    """
    Uses Sefaria Project to create a list of titles of every Talmud Tractate
    :return: Set of all Talmud book titles
    """
    indexes = library.all_index_records()
    talmud_books = set(library.get_indexes_in_category("Bavli"))
    talmud_books_modified = {u'Avodah Zarah',  u'Bava Batra', u'Bava Kamma',
     u'Bava Metzia', u'Beitzah', u'Berakhot', u'Chagigah', u'Eruvin', u'Gittin', u'Horayot',
     u'Ketubot', u'Kiddushin', u'Makkot', u'Megillah', u'Menachot', u'Moed Katan',
     u'Nazir', u'Nedarim', u'Pesachim', u'Rosh Hashanah', u'Sanhedrin', u'Shabbat', u'Shevuot',
     u'Sotah', u'Sukkah', u'Taanit',  u'Yevamot', u'Yoma', u'Zevachim'}
    return talmud_books_modified


def create_list_off_tanakh_books():
    """
    Uses Sefaria Project to create a list of titles of every book in Tanakh 
    :return: Set of all Tanakh book titles
    """
    indexes = library.all_index_records()
    tanakh_books = set(library.get_indexes_in_category("Tanakh"))
    tanakh_books_modified = set([u'Judges', u'Deuteronomy', u'Genesis', u'Exodus',
                             u'Leviticus', u'II Kings', u'Joshua',
                             u'I Samuel', u'Numbers', u'I Kings', u'II Samuel'])
    return tanakh_books_modified
    


def get_tanakh_topic_ranges():
    """
    Creates semantically meaningful ranged refs for Tanakh using Herzog's breakdown
    :return: List of all Tanakh Ranged Refs
    """
    with codecs.open('level_3_wo_overlaps.json', 'r', encoding='utf8' ) as the_file:
        segs = json.load(the_file, encoding='utf8')
    tanakh_topic_ranged_refs = []

    for seg in segs:
        b_ref = seg['b_ref']
        e_ref = seg['e_ref']
        book = b_ref.rsplit(' ', 1)[0]
        b_chapter = b_ref.rsplit(' ', 1)[1].split(':')[0]
        b_verse = b_ref.rsplit(' ', 1)[1].split(':')[1]
        e_chapter = e_ref.rsplit(' ', 1)[1].split(':')[0]
        e_verse = e_ref.rsplit(' ', 1)[1].split(':')[1]

        verses = "{}:{}-{}".format(b_chapter, b_verse, e_verse) if b_chapter == e_chapter else "{}:{}-{}:{}".format(b_chapter, b_verse, e_chapter, e_verse)
        tanakh_topic_ranged_refs.append("{} {}".format(book, verses))
    
    return tanakh_topic_ranged_refs
    

def segment_range_dicts(topic_ranged_refs):
    """
    Creates two dictionaries.  These are mappings between ranged refs and segments refs.  
    This receives a list of ranged refs.  It iterates over every ranged ref and creates a mapping between the ranged refs and the segment refs.
    :param topic_ranged_refs: list of ranged refs
    :return: tuple of dicts. The first is dict mapping ranged refs to all segment refs.  The second is a dict mapping each segment ref to its corresponding ranged ref.
    """
    ranged_to_segment = {}
    segment_to_ranged = {}

    for topic_ranged_ref in topic_ranged_refs:
        ranged_to_segment[topic_ranged_ref] = {}
        topic_seg_refs = Ref(topic_ranged_ref).range_list()
        for seg_ref in topic_seg_refs:
            ranged_to_segment[topic_ranged_ref][seg_ref.normal()] = ""
            segment_to_ranged[seg_ref.normal()] = topic_ranged_ref
            
    return ranged_to_segment, segment_to_ranged

def is_from_category(ref, books_in_category):
    """
    Checks to see if a tref belongs to a list of book within a particular category
    For Example:  Is Genesis 12:3 within Tanakh
    :param ref: tref to be examined
    :param books_in_category: List of books in category
    :return: Boolean Value determining if Tref is within category
    """
    try:
        if Ref(ref).index.title in books_in_category:
            return True
        else:
            return False
    except InputError:
        return False
    

def pull_out_suffix(string):
    """
    Receives a string of Hebrew Text.  Iterates over every hebrew word and splits each
    word into its root and suffix.  
    :param string: String of Hebrew Text
    :return: String with Hebrew compound words split into Root and Suffix
    """
    string = string.split()
    string = ' '.join([word_expander.get(word, word) for word in string])
    return string

def remove_stopwords(string):
    """
    Replaces Stopwords with a space character  
    :param string: String of Hebrew Text
    :return: String without stopwords
    """
    return re.sub(stopwords_regex, u' ', string)

def remove_dicta_prefix(string):
    """
    Removes prefixes that were detected by Dicta
    :param string: String of Hebrew Text
    :return: String without prefixes
    """
    return re.sub(ur'[\u05d0-\u05ea]+┉', u'', string)

def remove_punctuation(data):
    """
    Removes various punctation from Hebrew text.
    :param data: String of Hebrew Text
    :return: String without punctuation
    """
    data = re.sub(ur'־', u' ', data)
    data = re.sub(ur'\([^)]+\)', u' ', data)
    data = re.sub(ur'<[^>]+>', u' ', data)
    data = re.sub(ur'\[[^\]]+\]', u' ', data)
    data = re.sub(ur'[^ \u05d0-\u05ea"\'״׳]', u' ', data)
    data = re.sub(ur'(^|\s)["\'״׳]+', u' ', data)
    data = re.sub(ur'["\'״׳]+(\s|$)', u' ', data)
    return data

def strip_stopwords_and_remove_punctuation(data):
    """
    This method takes a string of hebrew text and does all necessary cleaning for Word2Vec.
    :param data: String of Hebrew Text
    :return: String ready for Word2Vec model
    """
    data = data.strip().split(u'~~')[1]
    data = remove_dicta_prefix(data)
    data = remove_punctuation(data)
    data = pull_out_suffix(data)
    data = remove_stopwords(data)
    data = u' '.join(data.split())
    return data



def create_multiple_word_phrases(data):
    """
    Combines selected multiple word phrases with underscore. 
    For example:  New York ----> New_York
    This allows Word2Vec to handle multiple word phrases
    :param data: String of Hebrew Text
    :return: String with connected multiple word phrases
    """
    def connect_with_underscore(matchobj):
        return matchobj.group(1) + matchobj.group(2).replace(u" ", u"_")
    return re.sub(phrases_regex, connect_with_underscore, data)


def this_is_a_bad_line(data):
    """
    Checks to see if a line from the file should be included in the Word2Vec model.
    There are some lines within the Dicta Prefix file that we cannot or do not want to include.
    :param data: line of hebrew text from Dicta File
    :return: Boolean Value determining if this line valid
    """
    if u'~~' not in data:
        return True
    if data.strip().split(u'~~')[1].strip().startswith(u"<br><br><big><strong>הדרן עלך"):
        return True
    
    return False
    

def get_segments(filename):
    """
    Combs through the entire Sefaris Hebrew Library and cleans the text for Doc2Vec.
    Creates a dict:
        Key:  Ref
        Value:  The text of that ref cleaned and ready for Doc2Vec
    :param filename: Dicta Prefix Filename
    :return: Dict for Doc2Vec
    """
    
    all_tanakh_books = create_list_off_tanakh_books()
    all_talmud_books = create_list_off_talmud_books()
    
    all_data = {}
    
    
    tanakh_topic_ranged_refs = get_tanakh_topic_ranges()
    talmud_topic_ranged_refs = get_talmud_topic_ranged()
    
    tanakh_ranged_to_segment, tanakh_segment_to_ranged = segment_range_dicts(tanakh_topic_ranged_refs)
    talmud_ranged_to_segment, talmud_segment_to_ranged = segment_range_dicts(talmud_topic_ranged_refs)


    for index, data in enumerate(codecs.open(filename, encoding='utf8')):
        
        if this_is_a_bad_line(data):
            continue
            
        ref = data.split(u'~')[0]
        data = strip_stopwords_and_remove_punctuation(data)
        data = create_multiple_word_phrases(data)
        
          
        if index%100000 == 0:
            print index
            
        if is_from_category(ref, all_tanakh_books):
            this_ref_ranged_reg = tanakh_segment_to_ranged[ref]        
            tanakh_ranged_to_segment[this_ref_ranged_reg][ref] = data
        elif is_from_category(ref, all_talmud_books):
            this_ref_ranged_reg = talmud_segment_to_ranged[ref]
            talmud_ranged_to_segment[this_ref_ranged_reg][ref] = data
        else:
            all_data[ref] = data
            
    for text_ranged_ref in tanakh_topic_ranged_refs:
        object_ref = Ref(text_ranged_ref)
        all_text_subrefs = [seg_ref.normal() for seg_ref in object_ref.range_list()]
        all_verses = [tanakh_ranged_to_segment[text_ranged_ref][seg_ref] for seg_ref in all_text_subrefs]
        all_data[text_ranged_ref] = u' '.join(all_verses)
        
    for text_ranged_ref in talmud_topic_ranged_refs:
        object_ref = Ref(text_ranged_ref)
        all_text_subrefs = [seg_ref.normal() for seg_ref in object_ref.range_list()]
        all_verses = [talmud_ranged_to_segment[text_ranged_ref][seg_ref] for seg_ref in all_text_subrefs]
        all_data[text_ranged_ref] = u' '.join(all_verses)
    
    return all_data

# %%
segments = get_segments('./sefaria-export_prefix_refs.txt')
# Out:
# 0
# 100000
# 200000
# 300000
# 400000
# 500000
# 600000
# 700000
# 800000
# 900000
# 1000000
# 1100000
# 1200000
# 1300000
# 1400000
# 1500000
# 1600000

# %%
all_clean_docs_filename = 'cleaned_docs_for_doc2vec.txt'
with codecs.open(all_clean_docs_filename, 'wb', encoding='utf8') as the_file:
    for k, v in segments.items():
        the_file.write(u""+k+u"||||"+v+u"\n")

# %% [markdown]
# Initiate a SegmentGenerator object to pass to the model

# %%
class SegmentGenerator(object):
    def __init__(self, segments_filename):
        self.segments_filename = segments_filename

    def __iter__(self):
        with codecs.open(self.segments_filename, 'rb', encoding='utf8') as the_file:
            for line in the_file:
                ref = line.split(u"||||")[0]
                data = line.split(u"||||")[1]
                yield gen.models.doc2vec.TaggedDocument(gen.utils.simple_preprocess(data), [ref])

# %%
segments_generator = SegmentGenerator(all_clean_docs_filename)

# %% [markdown]
# ### Model intiation

# %%
model = gen.models.doc2vec.Doc2Vec(vector_size=100, min_count=2, epochs=40, dm=0, dbow_words=1)

# %% [markdown]
# Now we have initiated the Word2Vec model. The next step is to call the **build_vocab** method for the preliminary scan of the text. Call the method and print how many words are in the vocabulary of our text

# %%
model.build_vocab(segments_generator)
print("Number of words in vocabulary: {}".format(len(model.wv.vocab)))
# Out:
# INFO collecting all words and their counts
# INFO PROGRESS: at example #0, processed 0 words (0/s), 0 word types, 0 tags
# INFO PROGRESS: at example #10000, processed 480183 words (493516/s), 29343 word types, 10000 tags
# INFO PROGRESS: at example #20000, processed 951957 words (444592/s), 39961 word types, 20000 tags
# INFO PROGRESS: at example #30000, processed 1425416 words (464963/s), 48038 word types, 30000 tags
# INFO PROGRESS: at example #40000, processed 1894717 words (512670/s), 54567 word types, 40000 tags
# INFO PROGRESS: at example #50000, processed 2365377 words (501974/s), 60171 word types, 50000 tags
# INFO PROGRESS: at example #60000, processed 2823417 words (497557/s), 64944 word types, 60000 tags
# INFO PROGRESS: at example #70000, processed 3297189 words (506217/s), 69025 word types, 70000 tags
# INFO PROGRESS: at example #80000, processed 3766242 words (410361/s), 73037 word types, 80000 tags
# INFO PROGRESS: at example #90000, processed 4241438 words (506678/s), 76961 word types, 90000 tags
# INFO PROGRESS: at example #100000, processed 4707206 words (486392/s), 80225 word types, 100000 tags
# INFO PROGRESS: at example #110000, processed 5162401 words (491577/s), 83640 word types, 110000 tags
# INFO PROGRESS: at example #120000, processed 5621945 words (487273/s), 86713 word types, 120000 tags
# INFO PROGRESS: at example #130000, processed 6111972 words (473025/s), 89923 word types, 130000 tags
# INFO PROGRESS: at example #140000, processed 6597731 words (477518/s), 92807 word types, 140000 tags
# INFO PROGRESS: at example #150000, processed 7073808 words (493122/s), 95537 word types, 150000 tags
# INFO PROGRESS: at example #160000, processed 7548767 words (498903/s), 98202 word types, 160000 tags
# INFO PROGRESS: at example #170000, processed 7995475 words (467716/s), 100668 word types, 170000 tags
# INFO PROGRESS: at example #180000, processed 8479005 words (486636/s), 103237 word types, 180000 tags
# INFO PROGRESS: at example #190000, processed 8965895 words (468916/s), 105663 word types, 190000 tags
# INFO PROGRESS: at example #200000, processed 9416434 words (366568/s), 107810 word types, 200000 tags
# INFO PROGRESS: at example #210000, processed 9879811 words (464153/s), 110035 word types, 210000 tags
# INFO PROGRESS: at example #220000, processed 10356085 words (499504/s), 112389 word types, 220000 tags
# INFO PROGRESS: at example #230000, processed 10844674 words (501152/s), 114742 word types, 230000 tags
# INFO PROGRESS: at example #240000, processed 11305533 words (497491/s), 116659 word types, 240000 tags
# INFO PROGRESS: at example #250000, processed 11786404 words (502487/s), 118644 word types, 250000 tags
# INFO PROGRESS: at example #260000, processed 12253527 words (498712/s), 120675 word types, 260000 tags
# INFO PROGRESS: at example #270000, processed 12728467 words (495065/s), 122694 word types, 270000 tags
# INFO PROGRESS: at example #280000, processed 13196356 words (499509/s), 124619 word types, 280000 tags
# INFO PROGRESS: at example #290000, processed 13680479 words (507528/s), 126508 word types, 290000 tags
# INFO PROGRESS: at example #300000, processed 14165099 words (498679/s), 128527 word types, 300000 tags
# INFO PROGRESS: at example #310000, processed 14633947 words (499405/s), 130280 word types, 310000 tags
# INFO PROGRESS: at example #320000, processed 15097933 words (497857/s), 131889 word types, 320000 tags
# INFO PROGRESS: at example #330000, processed 15564554 words (495161/s), 133663 word types, 330000 tags
# INFO PROGRESS: at example #340000, processed 16047131 words (509074/s), 135426 word types, 340000 tags
# INFO PROGRESS: at example #350000, processed 16528317 words (487438/s), 137102 word types, 350000 tags
# INFO PROGRESS: at example #360000, processed 16992728 words (385678/s), 138716 word types, 360000 tags
# INFO PROGRESS: at example #370000, processed 17459314 words (496587/s), 140194 word types, 370000 tags
# INFO PROGRESS: at example #380000, processed 17941815 words (497308/s), 141976 word types, 380000 tags
# INFO PROGRESS: at example #390000, processed 18425494 words (511493/s), 143586 word types, 390000 tags
# INFO PROGRESS: at example #400000, processed 18879190 words (492661/s), 145130 word types, 400000 tags
# INFO PROGRESS: at example #410000, processed 19354118 words (503893/s), 146581 word types, 410000 tags
# INFO PROGRESS: at example #420000, processed 19827661 words (501680/s), 148164 word types, 420000 tags
# INFO PROGRESS: at example #430000, processed 20287581 words (493520/s), 149604 word types, 430000 tags
# INFO PROGRESS: at example #440000, processed 20731012 words (490291/s), 151023 word types, 440000 tags
# INFO PROGRESS: at example #450000, processed 21190904 words (498795/s), 152321 word types, 450000 tags
# INFO PROGRESS: at example #460000, processed 21676039 words (487313/s), 153989 word types, 460000 tags
# INFO PROGRESS: at example #470000, processed 22143892 words (500792/s), 155431 word types, 470000 tags
# INFO PROGRESS: at example #480000, processed 22595090 words (493761/s), 156769 word types, 480000 tags
# INFO PROGRESS: at example #490000, processed 23069809 words (497009/s), 158075 word types, 490000 tags
# INFO PROGRESS: at example #500000, processed 23541175 words (500073/s), 159463 word types, 500000 tags
# INFO PROGRESS: at example #510000, processed 23999573 words (474654/s), 160802 word types, 510000 tags
# INFO PROGRESS: at example #520000, processed 24504548 words (414534/s), 162198 word types, 520000 tags
# INFO PROGRESS: at example #530000, processed 24944456 words (442983/s), 163499 word types, 530000 tags
# INFO PROGRESS: at example #540000, processed 25402045 words (494520/s), 164807 word types, 540000 tags
# INFO PROGRESS: at example #550000, processed 25867080 words (450814/s), 166110 word types, 550000 tags
# INFO PROGRESS: at example #560000, processed 26345904 words (316561/s), 167317 word types, 560000 tags
# INFO PROGRESS: at example #570000, processed 26831921 words (449378/s), 168489 word types, 570000 tags
# INFO PROGRESS: at example #580000, processed 27287310 words (499445/s), 169658 word types, 580000 tags
# INFO PROGRESS: at example #590000, processed 27763317 words (436195/s), 170903 word types, 590000 tags
# INFO PROGRESS: at example #600000, processed 28248368 words (415449/s), 172304 word types, 600000 tags
# INFO PROGRESS: at example #610000, processed 28705378 words (388206/s), 173443 word types, 610000 tags
# INFO PROGRESS: at example #620000, processed 29140286 words (392120/s), 174605 word types, 620000 tags
# INFO PROGRESS: at example #630000, processed 29611834 words (425413/s), 175853 word types, 630000 tags
# INFO PROGRESS: at example #640000, processed 30099393 words (462707/s), 176973 word types, 640000 tags
# INFO PROGRESS: at example #650000, processed 30560224 words (343668/s), 178096 word types, 650000 tags
# INFO PROGRESS: at example #660000, processed 31032335 words (435902/s), 179330 word types, 660000 tags
# INFO PROGRESS: at example #670000, processed 31522748 words (403802/s), 180520 word types, 670000 tags
# INFO PROGRESS: at example #680000, processed 31986186 words (393097/s), 181623 word types, 680000 tags
# INFO PROGRESS: at example #690000, processed 32451329 words (477947/s), 182709 word types, 690000 tags
# INFO PROGRESS: at example #700000, processed 32926561 words (466986/s), 183848 word types, 700000 tags
# INFO PROGRESS: at example #710000, processed 33400653 words (479733/s), 184929 word types, 710000 tags
# INFO PROGRESS: at example #720000, processed 33886419 words (514915/s), 185957 word types, 720000 tags
# INFO PROGRESS: at example #730000, processed 34349188 words (493491/s), 187128 word types, 730000 tags
# INFO PROGRESS: at example #740000, processed 34817063 words (494190/s), 188190 word types, 740000 tags
# INFO PROGRESS: at example #750000, processed 35303212 words (458654/s), 189462 word types, 750000 tags
# INFO PROGRESS: at example #760000, processed 35758175 words (496467/s), 190695 word types, 760000 tags
# INFO PROGRESS: at example #770000, processed 36217788 words (507878/s), 191803 word types, 770000 tags
# INFO PROGRESS: at example #780000, processed 36670573 words (502227/s), 192843 word types, 780000 tags
# INFO PROGRESS: at example #790000, processed 37128139 words (388388/s), 193790 word types, 790000 tags
# INFO PROGRESS: at example #800000, processed 37611106 words (377172/s), 194861 word types, 800000 tags
# INFO PROGRESS: at example #810000, processed 38059767 words (388978/s), 195819 word types, 810000 tags
# INFO PROGRESS: at example #820000, processed 38515852 words (259422/s), 196805 word types, 820000 tags
# INFO PROGRESS: at example #830000, processed 38986308 words (354775/s), 197946 word types, 830000 tags
# INFO PROGRESS: at example #840000, processed 39459622 words (365770/s), 198984 word types, 840000 tags
# INFO PROGRESS: at example #850000, processed 39914003 words (392453/s), 199844 word types, 850000 tags
# INFO PROGRESS: at example #860000, processed 40391398 words (438661/s), 200825 word types, 860000 tags
# INFO PROGRESS: at example #870000, processed 40861805 words (459527/s), 201860 word types, 870000 tags
# INFO PROGRESS: at example #880000, processed 41321675 words (402163/s), 203070 word types, 880000 tags
# INFO PROGRESS: at example #890000, processed 41820841 words (486125/s), 204106 word types, 890000 tags
# INFO PROGRESS: at example #900000, processed 42287064 words (489752/s), 205031 word types, 900000 tags
# INFO PROGRESS: at example #910000, processed 42747493 words (377988/s), 205862 word types, 910000 tags
# INFO PROGRESS: at example #920000, processed 43191639 words (486907/s), 206732 word types, 920000 tags
# INFO PROGRESS: at example #930000, processed 43650966 words (494004/s), 207658 word types, 930000 tags
# INFO PROGRESS: at example #940000, processed 44116824 words (469940/s), 208718 word types, 940000 tags
# INFO PROGRESS: at example #950000, processed 44593782 words (477424/s), 209608 word types, 950000 tags
# INFO PROGRESS: at example #960000, processed 45068294 words (461353/s), 210547 word types, 960000 tags
# INFO PROGRESS: at example #970000, processed 45520131 words (485705/s), 211452 word types, 970000 tags
# INFO PROGRESS: at example #980000, processed 45971563 words (498317/s), 212325 word types, 980000 tags
# INFO PROGRESS: at example #990000, processed 46454885 words (495309/s), 213283 word types, 990000 tags
# INFO PROGRESS: at example #1000000, processed 46916453 words (495003/s), 214154 word types, 1000000 tags
# INFO PROGRESS: at example #1010000, processed 47371592 words (483597/s), 215034 word types, 1010000 tags
# INFO PROGRESS: at example #1020000, processed 47832857 words (486425/s), 215979 word types, 1020000 tags
# INFO PROGRESS: at example #1030000, processed 48294612 words (495680/s), 216921 word types, 1030000 tags
# INFO PROGRESS: at example #1040000, processed 48784908 words (503335/s), 217950 word types, 1040000 tags
# INFO PROGRESS: at example #1050000, processed 49219248 words (485683/s), 218670 word types, 1050000 tags
# INFO PROGRESS: at example #1060000, processed 49687739 words (486480/s), 219467 word types, 1060000 tags
# INFO PROGRESS: at example #1070000, processed 50168120 words (484467/s), 220266 word types, 1070000 tags
# INFO PROGRESS: at example #1080000, processed 50662117 words (490665/s), 221175 word types, 1080000 tags
# INFO PROGRESS: at example #1090000, processed 51135088 words (419273/s), 222031 word types, 1090000 tags
# INFO PROGRESS: at example #1100000, processed 51612820 words (469217/s), 222945 word types, 1100000 tags
# INFO PROGRESS: at example #1110000, processed 52092419 words (443567/s), 223850 word types, 1110000 tags
# INFO PROGRESS: at example #1120000, processed 52547235 words (380628/s), 224728 word types, 1120000 tags
# INFO PROGRESS: at example #1130000, processed 53014371 words (333196/s), 225778 word types, 1130000 tags
# INFO PROGRESS: at example #1140000, processed 53493442 words (494933/s), 226685 word types, 1140000 tags
# INFO PROGRESS: at example #1150000, processed 53966555 words (497125/s), 227472 word types, 1150000 tags
# INFO PROGRESS: at example #1160000, processed 54429962 words (485710/s), 228257 word types, 1160000 tags
# INFO PROGRESS: at example #1170000, processed 54898449 words (461863/s), 229102 word types, 1170000 tags
# INFO PROGRESS: at example #1180000, processed 55373291 words (472354/s), 229924 word types, 1180000 tags
# INFO PROGRESS: at example #1190000, processed 55852459 words (360845/s), 230745 word types, 1190000 tags
# INFO PROGRESS: at example #1200000, processed 56309943 words (381654/s), 231545 word types, 1200000 tags
# INFO PROGRESS: at example #1210000, processed 56793838 words (455807/s), 232429 word types, 1210000 tags
# INFO PROGRESS: at example #1220000, processed 57256097 words (424626/s), 233204 word types, 1220000 tags
# INFO PROGRESS: at example #1230000, processed 57747229 words (473773/s), 234040 word types, 1230000 tags
# INFO PROGRESS: at example #1240000, processed 58218349 words (499709/s), 234834 word types, 1240000 tags
# INFO PROGRESS: at example #1250000, processed 58677874 words (454044/s), 235611 word types, 1250000 tags
# INFO PROGRESS: at example #1260000, processed 59171763 words (414441/s), 236486 word types, 1260000 tags
# INFO PROGRESS: at example #1270000, processed 59655576 words (477829/s), 237276 word types, 1270000 tags
# INFO PROGRESS: at example #1280000, processed 60139135 words (393145/s), 238226 word types, 1280000 tags
# INFO PROGRESS: at example #1290000, processed 60594963 words (471462/s), 238977 word types, 1290000 tags
# INFO PROGRESS: at example #1300000, processed 61072313 words (463800/s), 239768 word types, 1300000 tags
# INFO PROGRESS: at example #1310000, processed 61546605 words (498854/s), 240615 word types, 1310000 tags
# INFO PROGRESS: at example #1320000, processed 62017047 words (504826/s), 241488 word types, 1320000 tags
# INFO PROGRESS: at example #1330000, processed 62498644 words (416928/s), 242309 word types, 1330000 tags
# INFO PROGRESS: at example #1340000, processed 62965296 words (490839/s), 243058 word types, 1340000 tags
# INFO PROGRESS: at example #1350000, processed 63442731 words (467168/s), 243916 word types, 1350000 tags
# INFO PROGRESS: at example #1360000, processed 63910408 words (481576/s), 244642 word types, 1360000 tags
# INFO PROGRESS: at example #1370000, processed 64361016 words (487169/s), 245334 word types, 1370000 tags
# INFO PROGRESS: at example #1380000, processed 64830483 words (456731/s), 246102 word types, 1380000 tags
# INFO PROGRESS: at example #1390000, processed 65318991 words (433514/s), 246857 word types, 1390000 tags
# INFO PROGRESS: at example #1400000, processed 65797489 words (410417/s), 247710 word types, 1400000 tags
# INFO PROGRESS: at example #1410000, processed 66285677 words (425977/s), 248463 word types, 1410000 tags
# INFO PROGRESS: at example #1420000, processed 66743720 words (358776/s), 249214 word types, 1420000 tags
# INFO PROGRESS: at example #1430000, processed 67226862 words (435795/s), 249953 word types, 1430000 tags
# INFO PROGRESS: at example #1440000, processed 67716891 words (461024/s), 250703 word types, 1440000 tags
# INFO PROGRESS: at example #1450000, processed 68200847 words (489491/s), 251555 word types, 1450000 tags
# INFO PROGRESS: at example #1460000, processed 68662086 words (485924/s), 252249 word types, 1460000 tags
# INFO PROGRESS: at example #1470000, processed 69137928 words (485530/s), 253020 word types, 1470000 tags
# INFO PROGRESS: at example #1480000, processed 69605075 words (476669/s), 253758 word types, 1480000 tags
# INFO PROGRESS: at example #1490000, processed 70076169 words (490202/s), 254478 word types, 1490000 tags
# INFO PROGRESS: at example #1500000, processed 70547096 words (455984/s), 255221 word types, 1500000 tags
# INFO PROGRESS: at example #1510000, processed 71023435 words (306855/s), 255949 word types, 1510000 tags
# INFO PROGRESS: at example #1520000, processed 71492092 words (456152/s), 256771 word types, 1520000 tags
# INFO PROGRESS: at example #1530000, processed 71989392 words (483385/s), 257515 word types, 1530000 tags
# INFO PROGRESS: at example #1540000, processed 72471610 words (468699/s), 258259 word types, 1540000 tags
# INFO PROGRESS: at example #1550000, processed 72946418 words (489503/s), 259014 word types, 1550000 tags
# INFO collected 259021 word types and 1550133 unique tags from a corpus of 1550133 examples and 72952683 words
# INFO Loading a fresh vocabulary
# INFO effective_min_count=2 retains 151713 unique words (58% of original 259021, drops 107308)
# INFO effective_min_count=2 leaves 72845375 word corpus (99% of original 72952683, drops 107308)
# INFO deleting the raw counts dictionary of 259021 items
# INFO sample=0.001 downsamples 24 most-common words
# INFO downsampling leaves estimated 71459864 word corpus (98.1% of prior 72845375)
# INFO estimated required memory for 151713 words and 100 dimensions: 1127306700 bytes
# INFO resetting layer weights
# Number of words in vocabulary: 151713

# %% [markdown]
# In the previous step we created the vocabulary for our model, it is now time to train! Don't forget to add the following parameters:
# 1. total_examples=model.corpus_count
# 2. epochs=model.epochs

# %%
model.train(segments_generator, total_examples=model.corpus_count, epochs=10)
# Out:
# INFO training model with 3 workers on 151713 vocabulary and 100 features, using sg=1 hs=0 sample=0.001 negative=5 window=5
# INFO EPOCH 1 - PROGRESS: at 0.13% examples, 94930 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 0.30% examples, 104231 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 0.49% examples, 115582 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 0.70% examples, 120362 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 0.90% examples, 123805 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 1.11% examples, 126287 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 1.31% examples, 127989 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 1.50% examples, 128699 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 1.71% examples, 130050 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 1.91% examples, 131641 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 2.09% examples, 132014 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 2.30% examples, 132531 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 2.48% examples, 132942 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 2.68% examples, 133214 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 2.89% examples, 133936 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 3.09% examples, 134075 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 3.29% examples, 134405 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 3.50% examples, 134748 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 3.72% examples, 135239 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 3.93% examples, 135221 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 4.13% examples, 135669 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 4.31% examples, 135749 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 4.50% examples, 135860 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 4.72% examples, 136056 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 4.91% examples, 136119 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 5.12% examples, 136244 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 5.32% examples, 136230 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 5.48% examples, 135466 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 5.63% examples, 134802 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 5.81% examples, 134429 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 5.97% examples, 134149 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 6.17% examples, 134212 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 6.39% examples, 134410 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 6.59% examples, 134569 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 6.80% examples, 134595 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 7.01% examples, 134603 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 7.22% examples, 134776 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 7.42% examples, 134886 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 7.61% examples, 134693 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 7.79% examples, 134875 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 7.99% examples, 134814 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 8.19% examples, 135034 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 8.38% examples, 135083 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 8.54% examples, 134601 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 8.70% examples, 134194 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 8.86% examples, 133746 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 9.00% examples, 133254 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 9.18% examples, 133001 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 9.36% examples, 133069 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 9.56% examples, 133050 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 9.75% examples, 133131 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 9.91% examples, 133038 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 10.11% examples, 132972 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 10.29% examples, 132997 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 10.49% examples, 133006 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 10.70% examples, 133160 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at 10.91% examples, 133156 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 1 - PROGRESS: at
words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 94.53% examples, 136080 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 94.73% examples, 136085 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 94.94% examples, 136098 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 95.13% examples, 136091 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 95.34% examples, 136109 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 95.54% examples, 136111 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 95.72% examples, 136107 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 95.90% examples, 136096 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 96.12% examples, 136092 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 96.32% examples, 136101 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 96.53% examples, 136107 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 96.72% examples, 136107 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 96.95% examples, 136118 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 97.14% examples, 136134 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 97.32% examples, 136132 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 97.51% examples, 136132 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 97.71% examples, 136149 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 97.89% examples, 136145 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 98.08% examples, 136143 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 98.29% examples, 136148 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 98.49% examples, 136140 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 98.67% examples, 136155 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 98.85% examples, 136167 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 99.08% examples, 136160 words/s, in_qsize 6, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 99.27% examples, 136173 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 99.47% examples, 136185 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 99.65% examples, 136183 words/s, in_qsize 5, out_qsize 0
# INFO EPOCH 10 - PROGRESS: at 99.86% examples, 136192 words/s, in_qsize 6, out_qsize 0
# INFO worker thread finished; awaiting finish of 2 more threads
# INFO worker thread finished; awaiting finish of 1 more threads
# INFO worker thread finished; awaiting finish of 0 more threads
# INFO EPOCH - 10 : training on 72952683 raw words (72993034 effective words) took 535.8s, 136228 effective words/s
# INFO training on a 729526830 raw words (729932465 effective words) took 5397.7s, 135230 effective words/s

# %%
test_topics = [u"פסח", u"תפילה", u"משה", u"אברהם", u"צדקה", u"שבת", u"רות", u"אסתר", u"תשובה", u"חטא", u"חגים", u"קהילה", u"ישראל", u"צדק", u"התגלות", u"אהבה", u"מין", u"תפילין", u"סביבה"]

# %%
def get_ref_score(ref):
    score = 0
    try:
        score = 1-spatial.distance.cosine(model.docvecs[ref], model[u'פסח']) 
    except KeyError:
        pass
    return score


test_topics_dict = {}
for topic in test_topics:
    test_topics_dict[topic] = {}
    topic_sources = model.docvecs.most_similar([model[topic]], topn=3000)
    topic_sources = [x[0] for x in topic_sources]
    set_of_related = set(topic_sources)
    for tref in topic_sources:
        try:
            oref = Ref(tref)
        except PartialRefInputError:
            continue
        for l in oref.linkset():
            for other_ref in l.refs:
                if other_ref != tref:
                    set_of_related.add(other_ref)
    print len(set_of_related)
    final_scores = {}
    for tref in set_of_related:
        try:
            if not Ref(tref).is_segment_level():
                continue
        except InputError:
            continue

        final_scores[tref] = get_ref_score(tref)
        try:
            oref = Ref(tref)
        except InputError:
            print tref
            continue
        for l in oref.linkset():
            for other_ref in l.refs:
                if other_ref != tref:
                    try:
                        other_oref = Ref(other_ref)
                    except InputError:
                        continue
                    if other_oref.is_segment_level():
                        final_scores[tref] += get_ref_score(other_ref)
    final_scores = sorted(final_scores.items(), key=lambda x: x[1], reverse=True)
    for top_source in final_scores[:100]:
        test_topics_dict[topic][top_source[0]] = top_source[1]
# Out:
# 6645
# 6100
# 5354
# 7285
# 6111
# 6109
# 7745
# 7344
# 3993
# 5056
# 6052
# 3521
# 5853
# 8124
# 4154
# 5105
# 5900
# 6217
# 7724

# %%
with codecs.open('test_topics.json', 'w', encoding='utf8') as the_file:
    json.dump(test_topics_dict, the_file, indent=2, ensure_ascii=False)
